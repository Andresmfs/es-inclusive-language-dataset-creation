# %% [markdown]
# ## Profesiones feminizadas

# %%
import numpy as np
import pandas as pd
import random

# %%
sujeto1 = ['mi prima', 'mi hermana', 'mi madre', 'mi tía', 'mi amiga', 
           'mi cuñada', 'mi abuela', 'mi novia', 'mi mujer']
pre_sujeto = ['la prima de', 'la hermana de', 'la mujer de', 'la madre de', 'la tía de', 
              'la cuñada de', 'la amiga de', 'la novia de']

sujeto1_masc = ['mi primo', 'mi hermano', 'mi padre', 'mi tío', 'mi amigo', 
           'mi cuñado', 'mi abuelo', 'mi novio', 'mi marido']
pre_sujeto_masc = ['el primo de', 'el hermano de', 'el marido de', 'el padre de', 'el tío de', 
              'el cuñado de', 'el amigo de', 'el novio de']

nombres_varon = [
    "Juan", "Pedro", "Carlos", "Luis", "José", "Miguel", "Antonio", "Manuel", "Javier", "Francisco",
    "Daniel", "David", "Mario", "Alberto", "Sergio", "Fernando", "Pablo", "Rafael", "Alejandro", "Andrés",
    "Diego", "Ricardo", "Roberto", "Gabriel", "Ángel", "Jorge", "Emilio", "Fernando", "Gonzalo", "Ignacio",
    "Hugo", "Ismael", "Josué", "Joaquín", "Raúl", "Rubén", "Simón", "Tomás", "Víctor"]


nombres_mujer = [
    "María",
    "Ana",
    "Laura",
    "Luisa",
    "Sofía",
    "Elena",
    "Lucía",
    "Isabel",
    "Carmen",
    "Rosa",
    "Marta",
    "Patricia",
    "Paula",
    "Eva",
    "Clara",
    "Beatriz",
    "Natalia",
    "Diana",
    "Carolina",
    "Victoria",
    "Sara",
    "Lorena",
    "Adriana",
    "Alejandra",
    "Cristina",
    "Silvia",
    "Miriam",
    "Alicia",
    "Eva",
    "Teresa",
    "Raquel",
    "Inés",
    "Lidia",
    "Marina",
    "Andrea",
    "Rocío",
    "Nerea"
]

profesiones_hombres = [
    "Ingeniero",
    "Médico",
    "Abogado",
    "Gerente",
    "Programador",
    "Contador",
    "Administrador",
    "Policía",
    "Ejecutivo de ventas",
    "Electricista",
    "Mecánico",
    "Carpintero",
    "Fontanero",
    "Chef",
    "Periodista",
    "Fotógrafo",
    "Bombero",
    "Actor",
    "Cantante",
    "Escritor",
    "Artista plástico",
    "Economista",
    "Piloto",
    "Farmacéutico",
    "Ingeniero civil",
    "Arquitecto",
    "Diseñador gráfico",
    "Técnico de sistemas",
    "Psicólogo",
    "Abogado",
    "Vendedor",
    "Entrenador",
    "Investigador",
    "Analista financiero",
    "Consultor",
    "Recepcionista",
    "Soldador",
    "Soldado",
    "Conductor de autobús",
    "Conductor de camión",
    "Científico",
    "Asistente administrativo",
    "Asistente social",
    "Asesor financiero",
    "Médico de familia",
    "Dentista",
    "Veterinario",
    "Científico de datos",
    "Instructor de fitness"
]

profesiones_hombres = [x.lower() for x in profesiones_hombres]

profesiones_hombre_femenino = [
    "Ingeniera",
    "Médica",
    "Abogada",
    "Gerente",
    "Programadora",
    "Contable",
    "Administradora",
    "Policía",
    "Ejecutiva de ventas",
    "Electricista",
    "Mecánica",
    "Carpintera",
    "Fontanera",
    "Chef",
    "Periodista",
    "Fotógrafa",
    "Bombera",
    "Actriz",
    "Cantante",
    "Escritora",
    "Artista plástica",
    "Economista",
    "Piloto",
    "Farmacéutica",
    "Ingeniera civil",
    "Arquitecta",
    "Diseñadora gráfica",
    "Técnica de sistemas",
    "Psicóloga",
    "Abogada",
    "Vendedora",
    "Entrenadora",
    "Investigadora",
    "Analista financiera",
    "Consultora",
    "Recepcionista",
    "Soldadora",
    "Soldado",
    "Conductora de autobús",
    "Conductora de camión",
    "Científica",
    "Asistente administrativa",
    "Asistente social",
    "Asesora financiera",
    "Médica de familia",
    "Dentista",
    "Veterinaria",
    "Científica de datos",
    "Instructora de fitness"
]

profesiones_hombre_femenino = [x.lower() for x in profesiones_hombre_femenino]

profesiones_mujeres = [
    "Profesora",
    "Enfermera",
    "Secretaria",
    "Asistente administrativa",
    "Asistente social",
    "Recepcionista",
    "Maestra",
    "Asistente ejecutiva",
    "Psicóloga",
    "Abogada",
    "Contadora",
    "Administradora",
    "Cajera",
    "Vendedora",
    "Cocinera",
    "Esteticista",
    "Peluquera",
    "Médica",
    "Dentista",
    "Veterinaria",
    "Diseñadora gráfica",
    "Artista plástica",
    "Escritora",
    "Periodista",
    "Actriz",
    "Modelo",
    "Cantante",
    "Bailarina",
    "Directora de marketing",
    "Ejecutiva de ventas",
    "Consultora",
    "Coach",
    "Nutricionista",
    "Entrenadora personal",
    "Psiquiatra",
    "Ingeniera",
    "Arquitecta",
    "Diseñadora de moda",
    "Ingeniera de software",
    "Desarrolladora web",
    "Investigadora",
    "Científica",
    "Instructora de yoga",
    "Fotógrafa",
    "Piloto",
    "Ingeniera civil",
    "Marina",
    "Astronauta",
    "Oficial de policía",
    "Bombera"
]

profesiones_mujeres = [x.lower() for x in profesiones_mujeres]

profesiones_mujeres_masculino = [
    "Profesor",
    "Enfermero",
    "Secretario",
    "Asistente administrativo",
    "Asistente social",
    "Recepcionista",
    "Maestro",
    "Asistente ejecutivo",
    "Psicólogo",
    "Abogado",
    "Contable",
    "Administrador",
    "Cajero",
    "Vendedor",
    "Cocinero",
    "Esteticista",
    "Peluquero",
    "Médico",
    "Dentista",
    "Veterinario",
    "Diseñador gráfico",
    "Artista plástico",
    "Escritor",
    "Periodista",
    "Actor",
    "Modelo",
    "Cantante",
    "Bailarín",
    "Director de marketing",
    "Ejecutivo de ventas",
    "Consultor",
    "Entrenador",
    "Nutricionista",
    "Entrenador personal",
    "Psiquiatra",
    "Ingeniero",
    "Arquitecto",
    "Diseñador de moda",
    "Ingeniero de software",
    "Desarrollador web",
    "Investigador",
    "Científico",
    "Instructor de yoga",
    "Fotógrafo",
    "Piloto",
    "Ingeniero civil",
    "Marino",
    "Astronauta",
    "Oficial de policía",
    "Bombero"
]

profesiones_mujeres_masculino = [x.lower() for x in profesiones_mujeres_masculino]

profesiones_masculino = profesiones_hombres
for prof in profesiones_mujeres_masculino:
    profesiones_masculino.append(prof)

profesiones_femenino = profesiones_hombre_femenino
for prof in profesiones_mujeres:
    profesiones_femenino.append(prof)

profesiones_masculino = np.concatenate([profesiones_masculino, profesiones_masculino])
profesiones_femenino = np.concatenate([profesiones_femenino, profesiones_femenino])

# %% [markdown]
# ### Sujetos

# %%
import random

sujetos_femeninos = []

# 'la amiga de Carlos'
for nombre in nombres_varon:
    i = random.randint(0, len(pre_sujeto) - 1)
    sujetos_femeninos.append(pre_sujeto[i] + " " + nombre)

# 'la amiga de Clara'
for nombre in nombres_mujer:
    i = random.randint(0, len(pre_sujeto) - 1)
    sujetos_femeninos.append(pre_sujeto[i] + " " + nombre)
    sujetos_femeninos.append(nombre)

# 'la amiga de mi prima'
for i in range(2):
    for suj in sujeto1:
     i = random.randint(0, len(pre_sujeto) - 1)
     sujetos_femeninos.append(pre_sujeto[i] + ' ' + suj)
     # 'Clara'    
     sujetos_femeninos.append(suj)

# 'la amiga de mi primo'
    for suj in sujeto1_masc:
     i = random.randint(0, len(pre_sujeto) - 1)
     sujetos_femeninos.append(pre_sujeto[i] + ' ' + suj)



for suj in sujeto1:
# 'la amiga de mi prima Clara'
    i = random.randint(0, len(pre_sujeto) - 1)
    sujetos_femeninos.append(pre_sujeto[i] + ' ' + suj + ' ' + nombres_mujer[i])

for suj in sujeto1_masc:
# 'la amiga de mi primo Carlos'
    i = random.randint(0, len(pre_sujeto) - 1)
    sujetos_femeninos.append(pre_sujeto[i] + ' ' + suj + ' ' + nombres_varon[i])

print(len(sujetos_femeninos))
print(sujetos_femeninos)

sujetos_masculinos = []

## Sujetos masculinos
j = 20
for nombre in nombres_varon[:j]:
    i = random.randint(0, len(pre_sujeto_masc) - 1)
    sujetos_masculinos.append(pre_sujeto_masc[i] + " " + nombre)
    sujetos_masculinos.append(nombre)
    
for nombre in nombres_mujer[j:]:
    i = random.randint(0, len(pre_sujeto_masc) - 1)
    sujetos_masculinos.append(pre_sujeto_masc[i] + " " + nombre)
    


for suj in sujeto1:
    i = random.randint(0, len(pre_sujeto_masc) - 1)
    sujetos_masculinos.append(pre_sujeto_masc[i] + ' ' + suj)

for suj in sujeto1_masc:
    i = random.randint(0, len(pre_sujeto_masc) - 1)
    sujetos_masculinos.append(pre_sujeto_masc[i] + ' ' + suj)
    sujetos_masculinos.append(suj)

for suj in sujeto1:
# 'la amiga de mi prima Clara'
    i = random.randint(0, len(pre_sujeto) - 1)
    sujetos_masculinos.append(pre_sujeto_masc[i] + ' ' + suj + ' ' + nombres_mujer[i])

for suj in sujeto1_masc:
# 'la amiga de mi primo Carlos'
    i = random.randint(0, len(pre_sujeto) - 1)
    sujetos_masculinos.append(pre_sujeto_masc[i] + ' ' + suj + ' ' + nombres_varon[i])

print(len(sujetos_masculinos))
print(sujetos_masculinos)
# Out:
# 185
# ...

# %% [markdown]
# ### Frases

# %%
### Frases mujeres
union_neutra = ['era', 'es', 'trabaja de', 'está trabajando de']

adv_femenino = ['es muy buena', 'es una gran', 'era una fantástica']
union_adj_femenino = ['es una', 'era una']
adj_femenino = ['muy buena', 'fantástica', 'estupenda', 'buenísima', 
                'bastante buena', 'bastante mala', 'malísima']

union_pasado = ['era', 'trabajaba de', 'solía trabajar de', 'era una gran', 'era una fantástica', 'era muy buena']

beginnings = [
    "A pesar de su juventud, ",
    "Desde temprana edad ",
    "Durante los días laborales, ",
    "Con gran dedicación ",
    "Cada mañana ",
    "En la oficina ",
    "Después de graduarse ",
    "En su tiempo libre ",
    "Con entusiasmo ",
    "Durante años ",
    "Con experiencia previa ",
    "Al terminar la universidad ",
    "Durante la semana ",
    "En su puesto de trabajo ",
    "Desde muy temprano ",
    "Con habilidades excepcionales, ",
    "Tras obtener su título ",
    "Con pasión por su profesión ",
    "Desde la mañana hasta la noche ",
    "Con gran vocación, ",
    "Después de mucho esfuerzo ",
    "Durante la temporada alta ",
    "Con conocimientos sólidos, ",
    "Desde el amanecer ",
    "Con determinación ",
    "Desde la llegada de la primavera, ",
    "Desde el inicio de su carrera ",
    "Con dedicación sin igual ",
    "Desde la adolescencia, ",
    "Con compromiso profesional ",
    "Desde hace décadas, ",
    "Con el apoyo de su familia ",
    "Desde que comenzó a trabajar ",
    "Con meticulosidad ",
    "Desde la primera vez que pisó una obra, ",
    "Desde que se especializó en su área, ",
    "Con perseverancia, ",
    "Desde que se mudó a la ciudad, ",
    "Con entrega total, "
]


continuations = [
    "disfruta leyendo novelas de misterio.",
    "practica senderismo en las montañas cercanas.",
    "se dedica a pintar paisajes en su estudio.",
    "organiza eventos benéficos para su comunidad.",
    "asiste a clases de cocina para aprender nuevas recetas.",
    "cuida de su jardín y cultiva hermosas flores.",
    "toca el piano y compone sus propias melodías.",
    "se dedica a la fotografía y captura momentos especiales.",
    "viaja a diferentes países para explorar nuevas culturas.",
    "practica yoga para relajarse y mantenerse en forma.", 
    "disfruta de largas caminatas por el campo.",
    "dedica tiempo a la escritura de poesía.",
    "aprende un nuevo idioma en línea.",
    "participa en clases de baile para divertirse.",
    "realiza actividades de voluntariado en su comunidad.",
    "explora nuevas recetas de cocina de diferentes culturas.",
    "se reúne con colegas para jugar al ajedrez.",
    "visita museos y galerías de arte para inspirarse.",
    "se sumerge en la lectura de libros de filosofía.",
    "practica la meditación y la atención plena para encontrar calma interior.",
    "participa en actividades de voluntariado en su comunidad.",
    "disfruta haciendo manualidades y artesanías.",
    "se dedica a la jardinería y cultiva su propio huerto.",
    "aprende a tocar un nuevo instrumento musical.",
    "visita museos y exposiciones de arte.",
    "practica deportes acuáticos como el surf o el kayak.",
    "colabora con organizaciones ambientales en la protección del medio ambiente.",
    "se reúne con sus amigos y amigas para jugar a juegos de mesa.",
    "realiza excursiones fotográficas para capturar la belleza natural.",
    "organiza reuniones literarias para discutir libros con amigos.",
    "participa en grupos de debate y discusión sobre temas de actualidad.",
    "realiza actividades de meditación y mindfulness para relajarse.",
    "asiste a conciertos y recitales de música en vivo.",
    "practica deportes extremos como el paracaidismo o el parapente.",
    "explora nuevos restaurantes y cocina platos de diferentes culturas.",
    "realiza viajes en bicicleta para descubrir nuevos lugares.",
    "se involucra en la protección y rescate de animales.",
    "visita regularmente el teatro para disfrutar de obras de teatro.",
    "participa en clases de baile para aprender nuevos estilos.",
    "dedica tiempo a la escritura y la creación de poesía.",
    "explora la naturaleza haciendo camping y senderismo.",
    "practica actividades de mindfulness como la yoga y la meditación.",
    "participa en proyectos de arte comunitario en su vecindario.",
    "aprende nuevas habilidades de idiomas a través de cursos en línea.",
    "dedica tiempo a la lectura de libros de autoayuda y crecimiento personal.",
    "participa en actividades de rescate y ayuda en situaciones de emergencia.",
    "se une a grupos de música o coros para cantar y hacer música.",
    "realiza actividades de voluntariado en refugios de animales.",
    "se dedica a la costura y confección de sus propias prendas de vestir.",
    "organiza viajes de voluntariado para ayudar a comunidades necesitadas.",
    "aprende técnicas de cocina gourmet y realiza cenas especiales en casa.",
    "participa en talleres de arte y manualidades para adultos.",
    "se involucra en proyectos de construcción comunitaria.",
    "realiza actividades de observación de aves y vida silvestre.",
    "asiste a eventos culturales como festivales de cine y teatro.",
    "practica la fotografía de naturaleza y paisajes urbanos.",
    "participa en eventos deportivos locales como carreras y maratones.",
    "se involucra en proyectos de reforestación y conservación del medio ambiente.",
    "asiste a clases de cocina internacional para aprender platos exóticos.",
    "dedica tiempo a la escritura de su blog personal sobre sus pasiones.",
    "participa en programas de mentoría para ayudar a jóvenes talentos.",
    "se une a grupos de lectura para discutir y compartir libros favoritos."
]


contra_uniones = ['pero ahora es', 'y ahora se dedica trabajar como', 'aunque desde hace poco es', 'sin embargo desde el mes pasado trabaja de', 'y dijo que quería ser', 'y soñaba con ser', 'aunque le hubiera gustado ser']

sujetos_femeninos_shuf = sujetos_femeninos
random.shuffle(sujetos_femeninos)

# Frases
exclusive = []
inclusive = []

# Número tipos de frases
n = 10
m = round(len(sujetos_femeninos_shuf) / n)

for j in range(0, m):
    i = random.randint(0, len(union_neutra) - 1)
    inc = f'{sujetos_femeninos_shuf[j]} {union_neutra[i]} {profesiones_femenino[j]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{sujetos_femeninos_shuf[j]} {union_neutra[i]} {profesiones_masculino[j]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(m, 2*m):
    i = random.randint(0, len(adv_femenino) - 1)
    inc = f'{sujetos_femeninos_shuf[j]} {adv_femenino[i]} {profesiones_femenino[j]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{sujetos_femeninos_shuf[j]} {adv_femenino[i]} {profesiones_masculino[j]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(2*m, 3*m):
    i = random.randint(0, len(union_adj_femenino) - 1)
    k = random.randint(0, len(adj_femenino) - 1)
    inc = f'{sujetos_femeninos_shuf[j]} {union_adj_femenino[i]} {profesiones_femenino[j]} {adj_femenino[k]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{sujetos_femeninos_shuf[j]} {union_adj_femenino[i]} {profesiones_masculino[j]} {adj_femenino[k]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(3*m, 4*m):
    i = random.randint(0, len(beginnings) - 1)
    k = random.randint(0, len(union_pasado) - 1)
    inc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_femenino[j]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_masculino[j]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(4*m, 5*m):
    i = random.randint(0, len(beginnings) - 1)
    k = random.randint(0, len(union_pasado) - 1)
    l = random.randint(0, len(contra_uniones)-1)
    inc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_femenino[j]} {contra_uniones[l]} {profesiones_femenino[i]}'
    
    h = random.randint(0,2)
    if h == 0:
        exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_masculino[j]} {contra_uniones[l]} {profesiones_femenino[i]}'
    elif h == 1:
        exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_masculino[j]} {contra_uniones[l]} {profesiones_masculino[i]}'
    else:
        t = random.randint(0, 6)
        if t == 0:
            exc = inc
        else:
            exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_femenino[j]} {contra_uniones[l]} {profesiones_masculino[i]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(5*m, 6*m):
    i = random.randint(0, len(union_neutra) - 1)
    k = random.randint(0, len(continuations) - 1)
    inc = f'{sujetos_femeninos_shuf[j]} {union_neutra[i]} {profesiones_femenino[j]} y {continuations[k]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{sujetos_femeninos_shuf[j]} {union_neutra[i]} {profesiones_masculino[j]} y {continuations[k]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(6*m, 7*m):
    i = random.randint(0, len(union_adj_femenino) - 1)
    k = random.randint(0, len(adj_femenino) - 1)
    l = random.randint(0, len(continuations) - 1)
    inc = f'{sujetos_femeninos_shuf[j]} {union_adj_femenino[i]} {profesiones_femenino[j]} {adj_femenino[k]} y {continuations[l]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{sujetos_femeninos_shuf[j]} {union_adj_femenino[i]} {profesiones_masculino[j]} {adj_femenino[k]} y {continuations[l]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(7*m, 8*m):
    i = random.randint(0, len(union_adj_femenino) - 1)
    k = random.randint(0, len(adj_femenino) - 1)
    l = random.randint(0, len(beginnings) - 1)
    inc = f'{beginnings[l]} {sujetos_femeninos_shuf[j]} {union_adj_femenino[i]} {profesiones_femenino[j]} {adj_femenino[k]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{beginnings[l]} {sujetos_femeninos_shuf[j]} {union_adj_femenino[i]} {profesiones_masculino[j]} {adj_femenino[k]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(8*m, 9*m):
    i = random.randint(0, len(beginnings) - 1)
    k = random.randint(0, len(union_pasado) - 1)
    l = random.randint(0, len(contra_uniones)-1)
    g = random.randint(0, len(continuations) - 1)
    inc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_femenino[j]} {contra_uniones[l]} {profesiones_femenino[i]} y {continuations[g]}'
    
    h = random.randint(0,2)
    if h == 0:
        exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_masculino[j]} {contra_uniones[l]} {profesiones_femenino[i]} y {continuations[g]}'
    elif h == 1:
        exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_masculino[j]} {contra_uniones[l]} {profesiones_masculino[i]} y {continuations[g]}'
    else:
        t = random.randint(0, 5)
        if t == 0:
            exc = inc
        else:
            exc = f'{beginnings[i]} {sujetos_femeninos_shuf[j]} {union_pasado[k]} {profesiones_femenino[j]} {contra_uniones[l]} {profesiones_masculino[i]} y {continuations[g]}'
    exclusive.append(exc)
    inclusive.append(inc)

for j in range(9*m, len(sujetos_femeninos_shuf) - 2):
    i = random.randint(0, len(union_pasado) - 1)
    k = random.randint(0, len(beginnings) - 1)
    inc = f'{beginnings[k]}{sujetos_femeninos_shuf[j]} {union_pasado[i]} {profesiones_femenino[j]}'
    t = random.randint(0, 13)
    if t == 0:
        exc = inc
    else:
        exc = f'{beginnings[k]}{sujetos_femeninos_shuf[j]} {union_pasado[i]} {profesiones_masculino[j]}'
    exclusive.append(exc)
    inclusive.append(inc)





## frases hombre

union_pasado = ['era', 'trabajaba de', 'solía trabajar de', 'era un gran', 'era un fantástico', 'era muy buen']

adv_femenino = ['es muy buen', 'es un gran', 'era un fantástico']
union_adj_femenino = ['es un', 'era un']
adj_femenino = ['muy bueno', 'fantástico', 'estupendo', 'buenísimo', 
                'bastante bueno', 'bastante malo', 'malísimo']

sujetos_masculinos_shuf = sujetos_masculinos
random.shuffle(sujetos_masculinos)

j = 0
while j < 50:
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)

    inc = f'{beginnings[l]} {sujetos_masculinos_shuf[j]} {union_adj_femenino[i]} {profesiones_masculino[j]} {adj_femenino[k]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)
    
    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{beginnings[l]}{sujetos_masculinos_shuf[j]} {union_neutra[h]} {profesiones_masculino[j]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{beginnings[l]} {sujetos_masculinos_shuf[j]} {union_pasado[g]} {profesiones_masculino[j]} {contra_uniones[y]} {profesiones_masculino[i]} y {continuations[x]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{sujetos_masculinos_shuf[j]} {union_adj_femenino[i]} {profesiones_masculino[j]} {adj_femenino[k]} y {continuations[x]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{sujetos_masculinos_shuf[j]} {union_neutra[h]} {profesiones_masculino[j]} y {continuations[x]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{beginnings[l]} {sujetos_masculinos_shuf[j]} {union_pasado[g]} {profesiones_masculino[j]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{sujetos_masculinos_shuf[j]} {union_neutra[h]} {profesiones_masculino[j]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{sujetos_masculinos_shuf[j]} {adv_femenino[i]} {profesiones_masculino[j]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)

    j = j + 1
    l = random.randint(0, len(beginnings)-1) 
    i = random.randint(0, len(union_adj_femenino)-1)
    k = random.randint(0, len(adj_femenino)-1)
    h = random.randint(0, len(union_neutra)-1)
    g = random.randint(0, len(union_pasado)-1)
    y = random.randint(0, len(contra_uniones)-1)
    x = random.randint(0, len(continuations)-1)
    t = random.randint(0, len(adv_femenino)-1)
    inc = f'{sujetos_masculinos_shuf[j]} {adv_femenino[i]} {profesiones_masculino[j]}'
    exc = inc
    exclusive.append(exc)
    inclusive.append(inc)
    
# Create dataframe
df_profesiones_feminizadas = pd.DataFrame({'gender_exclusive': exclusive, 'gender_inclusive': inclusive})
df_profesiones_feminizadas['origin'] = 'human_combinatory'
df_profesiones_feminizadas['difficulty'] = 'feminizar_profesiones'

with pd.option_context('display.max_colwidth', None):
    display(df_profesiones_feminizadas.sample(25))
# Out:
#                                                                                                                                                               gender_exclusive  \
# 244                                                                                                                                       el padre de Mario es un gran maestro
# 176                                                                                                               Desde el amanecer la tía de mi tío era director de marketing
# 110                                                              Victoria era una carpintero malísima y se une a grupos de lectura para discutir y compartir libros favoritos.
# 117                                                                 mi amiga es una cantante bastante mala y practica actividades de mindfulness como la yoga y la meditación.
# ...

# %%
df_profesiones_feminizadas.to_csv('profesiones_feminizadas.csv', index=False)

# %% [markdown]
# ## Terminología

# %%
terminologia = pd.read_csv('palabras para crear frases.csv')
terminologia['gender_inclusive'].values
# Out:
# array(['persona transexual', 'persona con discapacidad',
#        'persona parapléjica', 'trasición de género',
#        'personas que no cumplen los mandatos de género',
#        'Personas que son independientes al género',
#        'persona con discapacidad', 'persona con discapacidad',
#        'personas sin papeles'], dtype=object)

# %%
sentences = [
    "El cambio de sexo es un proceso importante para muchas personas transexuales.",
    "Los transexuales merecen respeto y apoyo en su camino hacia la autenticidad.",
    "Es crucial crear espacios inclusivos para los transexuales en la sociedad.",
    "La comunidad transexual lucha por la igualdad de derechos y oportunidades.",
    # "El término 'parapléjico' se refiere a una persona con parálisis en las extremidades inferiores.",
    "Los discapacitados tienen derecho a la accesibilidad y la igualdad de oportunidades.",
    "Es fundamental eliminar las barreras arquitectónicas para los discapacitados.",
    "La sociedad debe trabajar para eliminar el estigma asociado con la discapacidad.",
    "Es importante ofrecer apoyo emocional a los discapacitados y sus familias.",
    # "Los términos 'inválido' y 'minusválido' son considerados despectivos en la actualidad.",
    # "Las personas con discapacidades merecen ser tratadas con dignidad y respeto.",
    "Los inmigrantes ilegales enfrentan numerosos desafíos al buscar una vida mejor.",
    "La situación de los inmigrantes ilegales es compleja y requiere soluciones humanitarias.",
    "Es necesario abordar las causas subyacentes de la migración ilegal para encontrar soluciones duraderas.",
    "Los derechos humanos deben proteger a todos, incluidos los inmigrantes ilegales."
]

sentences_inclusive = [
    "La transición de género es un proceso importante para muchas personas transexuales.",
    "Las personas transexuales merecen respeto y apoyo en su camino hacia la autenticidad.",
    "Es crucial crear espacios inclusivos para las personas transexuales en la sociedad.",
    "La comunidad de personas transexuales lucha por la igualdad de derechos y oportunidades.",
    # "El término 'persona parapléjica' se refiere a una persona con parálisis en las extremidades inferiores.",
    "Las personas con discapacidad tienen derecho a la accesibilidad y la igualdad de oportunidades.",
    "Es fundamental eliminar las barreras arquitectónicas para las personas con discapacidad.",
    "La sociedad debe trabajar para eliminar el estigma asociado con la discapacidad.",
    "Es importante ofrecer apoyo emocional a las personas con discapacidad y sus familias.",
    # "El término 'persona sin papeles' se refiere a personas que no tienen la documentación legal necesaria.",
    "Las personas extranjeras en situación administrativa irregular enfrentan numerosos desafíos al buscar una vida mejor.",
    "La situación de las personas extranjeras en situación administrativa irregular es compleja y requiere soluciones humanitarias.",
    "Es necesario abordar las causas subyacentes de la migración ilegal para encontrar soluciones duraderas.",
    "Los derechos humanos deben proteger a todos, incluidas las personas sin papeles."
]

# %%
df1 = pd.DataFrame({'gender_exclusive': sentences, 'gender_inclusive': sentences_inclusive})
df1['origin'] = 'GPT-3.5_fewshot'
df1['difficulty'] = 'terminologia'
df1
# Out:
#                                      gender_exclusive  \
# 0   El cambio de sexo es un proceso importante par...
# 1   Los transexuales merecen respeto y apoyo en su...
# 2   Es crucial crear espacios inclusivos para los ...
# 3   La comunidad transexual lucha por la igualdad ...
# 4   Los discapacitados tienen derecho a la accesib...
# 5   Es fundamental eliminar las barreras arquitect...
# 6   La sociedad debe trabajar para eliminar el est...
# 7   Es importante ofrecer apoyo emocional a los di...
# 8   Los inmigrantes ilegales enfrentan numerosos d...
# 9   La situación de los inmigrantes ilegales es co...
# 10  Es necesario abordar las causas subyacentes de...
# 11  Los derechos humanos deben proteger a todos, i...
#
#                                      gender_inclusive           origin  \
# 0   La transición de género es un proceso importan...  GPT-3.5_fewshot
# 1   Las personas transexuales merecen respeto y ap...  GPT-3.5_fewshot
# ...

# %% [markdown]
# ## Profesiones CCGG

# %%
prof_CCGG = pd.read_csv('profesiones.csv')
prof_CCGG = prof_CCGG.dropna()
prof_CCGG.plural_genérico.values
# Out:
# array(['Miembros del Congreso', 'Miembros del Senado', 'portavocía',
#        '(La) Portavocía adjunta', 'Presidencia', 'Vicepresidencia',
#        'Secretaría (tiene otro significado, habrá que atender especialmente al contexto)',
#        'Documentalistas', 'Personal del cuerpo técnico-administrativo',
#        'Equipo redactor', 'Personal del cuerpo administrativo',
#        'Dirección – Direcciones',
#        'Jefatura de (Departamento – Servicio – Área – Unidad)',
#        'Jefatura de la redacción',
#        'Responsabilidad de (Área – Secretaría) - Grupo responsable de (Área - Secretaría)',
#        'Portería (Puede tener problemas de ambigüedad)',
#        'Personas encargadas',
#        'Personal del garaje (o de la Unidad de garaje)',
#        'Funcionariado - personal funcionario',
#        'Personal laboral técnico (superior – intermedio –auxiliar)',
#        'Servicio médico', 'Personal de enfermería', 'Servicio de guías',
# ...

# %%
len(prof_CCGG.plural_masculino.values)
# Out:
# 30

# %%
sentences_CCGG = [
    "Los diputados y senadores discutieron en el pleno sobre el presupuesto nacional.",
    "Los portavoces del partido anunciaron su posición sobre la reforma fiscal.",
    "Los portavoces adjuntos expresaron su preocupación por el aumento del desempleo.",
    "El presidente de la cámara dio inicio a la sesión legislativa.",
    "Los vicepresidentes están a cargo de coordinar las comisiones parlamentarias.",
    "Los secretarios del comité elaboraron el acta de la reunión.",
    "Los archiveros bibliotecarios organizaron el sistema de documentación parlamentaria.",
    "Los técnicos administrativos gestionaron el flujo de información dentro del órgano legislativo.",
    "Los redactores redactaron el informe sobre las políticas de salud pública.",
    "Los administrativos se encargaron de la logística del evento parlamentario.",
    "Los directores de los departamentos presentaron sus informes anuales.",
    "Los jefes de departamento supervisaron la implementación del nuevo proyecto de ley.",
    "Los redactores jefes revisaron el discurso del presidente antes de su presentación.",
    "Los responsables de área coordinaron la agenda del comité de educación.",
    # "Los porteros aseguraron la entrada al edificio legislativo durante la sesión.",
    "Los encargados del mantenimiento repararon las instalaciones del parlamento.",
    "Los garajistas cuidaron de la flota de vehículos oficiales.",
    "Los funcionarios atendieron las consultas de los ciudadanos sobre legislación.",
    "Los técnicos intermedios asistieron en la actualización del sistema informático del parlamento.",
    "Los médicos de la cámara proporcionaron atención médica a los legisladores.",
    "Los enfermeros estuvieron disponibles en el dispensario parlamentario.",
    "Los guías llevaron a los visitantes en recorridos por el edificio legislativo.",
    "Los auxiliares de informática ayudaron en la configuración de los equipos audiovisuales.",
    "Los inspectores supervisaron el cumplimiento de las normativas de seguridad.",
    "Los inspectores jefes coordinaron las inspecciones de los comités legislativos.",
    "Los comisarios de la policía garantizaron la seguridad durante las protestas frente al parlamento.",
    "Los asesores proporcionaron asesoramiento jurídico a los legisladores.",
    "Los jefes de prensa coordinaron las comunicaciones del grupo parlamentario.",
    "Los empleados del grupo parlamentario organizaron una campaña de concientización ciudadana."
]

sentences_inclusive_CCGG = [
    "Los miembros del Congreso y del Senado discutieron en el pleno sobre el presupuesto nacional.",
    "La portavocía del partido anunció su posición sobre la reforma fiscal.",
    "La portavocía adjunta expresó su preocupación por el aumento del desempleo.",
    "La Presidencia de la cámara dio inicio a la sesión legislativa.",
    "La Vicepresidencia está a cargo de coordinar las comisiones parlamentarias.",
    "La Secretaría del comité elaboró el acta de la reunión.",
    "El equipo de documentalistas organizaron el sistema de documentación parlamentaria.",
    "El personal del cuerpo técnico-administrativo gestionó el flujo de información dentro del órgano legislativo.",
    "El equipo redactor redactó el informe sobre las políticas de salud pública.",
    "El personal del cuerpo administrativo se encargó de la logística del evento parlamentario.",
    "Las direcciones de los departamentos presentaron sus informes anuales.",
    "La jefatura de departamento supervisó la implementación del nuevo proyecto de ley.",
    "La jefatura de redacción revisó el discurso del presidente antes de su presentación.",
    "El grupo responsable de área coordinó la agenda del comité de educación.",
    # "La portería aseguró la entrada al edificio legislativo durante la sesión.",
    "Las personas encargadas del mantenimiento repararon las instalaciones del parlamento.",
    "El personal del garaje cuidó de la flota de vehículos oficiales.",
    "El funcionariado atendió las consultas de los ciudadanos sobre legislación.",
    "El personal laboral técnico asistió en la actualización del sistema informático del parlamento.",
    "El servicio médico de la cámara proporcionó atención médica a los legisladores.",
    "El personal de enfermería estuvo disponible en el dispensario parlamentario.",
    "El servicio de guías llevó a los visitantes en recorridos por el edificio legislativo.",
    "El personal auxiliar de informática ayudó en la configuración de los equipos audiovisuales.",
    "La inspección supervisó el cumplimiento de las normativas de seguridad.",
    "La jefatura de inspección coordinó las inspecciones de los comités legislativos.",
    "El comisariado de la policía garantizó la seguridad durante las protestas frente al parlamento.",
    "El personal de asesoría proporcionó asesoramiento jurídico a los legisladores.",
    "Los responsables de prensa coordinaron las comunicaciones del grupo parlamentario.",
    "El personal contratado por los grupos parlamentarios organizó una campaña de concientización ciudadana."
]

# %%
df2 = pd.DataFrame({'gender_exclusive': sentences_CCGG, 'gender_inclusive': sentences_inclusive_CCGG})
df2['origin'] = 'GPT-3.5_fewshot'
df2['difficulty'] = 'plurales'
df2
# Out:
#                                      gender_exclusive  \
# 0   Los diputados y senadores discutieron en el pl...
# 1   Los portavoces del partido anunciaron su posic...
# 2   Los portavoces adjuntos expresaron su preocupa...
# 3   El presidente de la cámara dio inicio a la ses...
# 4   Los vicepresidentes están a cargo de coordinar...
# 5   Los secretarios del comité elaboraron el acta ...
# 6   Los archiveros bibliotecarios organizaron el s...
# 7   Los técnicos administrativos gestionaron el fl...
# 8   Los redactores redactaron el informe sobre las...
# 9   Los administrativos se encargaron de la logíst...
# 10  Los directores de los departamentos presentaro...
# 11  Los jefes de departamento supervisaron la impl...
# 12  Los redactores jefes revisaron el discurso del...
# 13  Los responsables de área coordinaron la agenda...
# 14  Los encargados del mantenimiento repararon las...
# 15  Los garajistas cuidaron de la flota de vehícul...
# ...

# %%
df_merge = pd.concat([df1, df2])
df_merge.to_csv('terminologia_plurales.csv')
